# %% [markdown]
# ---
# ## Bài 1 (File) - Đọc và thống kê điểm
#
# File `scores.txt` chứa điểm của các sinh viên, mỗi dòng có dạng `Tên - Điểm`, ví dụ:
#
# ```
# Alice - 8.5
# Bob - 6.0
# ```
#
# Viết chương trình:
# 1. Đọc file `scores.txt`.
# 2. In ra tổng số sinh viên.
# 3. Tính và in ra **điểm trung bình** của cả lớp (làm tròn 2 chữ số).
# 4. In ra tên sinh viên có **điểm cao nhất**.
#
# *Gợi ý:* đọc từng dòng, dùng `line.strip().split(' - ')` để tách tên và điểm, nhớ `float()` cho điểm.

# %%
# Viết code Bài 1 tại đây

# %% [markdown]
# ---
# ## Bài 2 (File) - Đọc file kho hàng và tính tổng giá trị
#
# File `products.txt` có mỗi dòng dạng `tên - số_lượng`, ví dụ:
#
# ```
# apple - 10
# banana - 20
# orange - 30
# ```
#
# Viết chương trình:
# 1. Đọc file `products.txt`.
# 2. In danh sách sản phẩm kèm số lượng theo dạng `1. apple: 10`.
# 3. Tính và in ra **tổng số lượng** của tất cả sản phẩm.
#
# *Gợi ý:* dùng `readlines()` hoặc đọc từng dòng, tách bằng `split(' - ')` rồi `int()` cho số lượng.

# %%
# Viết code Bài 2 tại đây

# %% [markdown]
# ---
# ## Bài 3 (File) - Nhập và ghi danh sách thành phố ra file
#
# Viết chương trình:
# 1. Cho người dùng nhập tên các thành phố liên tục (mỗi lần một tên).
#    Khi người dùng gõ `done` thì dừng nhập.
# 2. Ghi tất cả các thành phố đã nhập vào file `my_cities.txt`, **mỗi thành phố một dòng**.
# 3. In ra thông báo `Đã lưu N thành phố vào my_cities.txt`.
#
# *Gợi ý:* dùng vòng `while`, mở file ở chế độ ghi `open('my_cities.txt', 'w')`, dùng `f.write(city + '\n')`.

# %%
# Viết code Bài 3 tại đây

# %% [markdown]
# ---
# ## Bài 4 (Đệ quy) - Tổng các chữ số của một số
#
# Viết hàm **đệ quy** `sum_digits(n)` trả về tổng các chữ số của số nguyên dương `n`.
#
# Ví dụ: `sum_digits(1234)` = 1 + 2 + 3 + 4 = **10**.
#
# *Gợi ý:*
# - Base case: nếu `n == 0` thì trả về 0.
# - Recursive case: `n % 10` là chữ số cuối, `n // 10` là phần còn lại → `n % 10 + sum_digits(n // 10)`.

# %%
def sum_digits(n):
    # Viết code Bài 4 tại đây
    pass

# Test
print(sum_digits(1234))   # 10
print(sum_digits(9))      # 9
print(sum_digits(100))    # 1

# %% [markdown]
# ---
# ## Bài 5 (Đệ quy) - Lũy thừa
#
# Viết hàm **đệ quy** `power(base, exp)` tính `base` mũ `exp` (với `exp` là số nguyên không âm), **không dùng** toán tử `**`.
#
# Ví dụ: `power(2, 5)` = **32**, `power(3, 0)` = **1**.
#
# *Gợi ý:*
# - Base case: nếu `exp == 0` thì trả về 1.
# - Recursive case: `base * power(base, exp - 1)`.

# %%
def power(base, exp):
    # Viết code Bài 5 tại đây
    pass

# Test
print(power(2, 5))   # 32
print(power(3, 0))   # 1
print(power(5, 3))   # 125
