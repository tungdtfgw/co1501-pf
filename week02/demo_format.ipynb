# %%
name = input('What is your name? ')
print(f'Hello, {name}!')
# Out:
# Hello, John!

# %%
yob = int(input('What is your year of birth? '))
print(f'You are {2026 - yob} years old.')
# Out:
# You are 26 years old.

# %%
a = int(input('Enter a: '))
b = int(input('Enter b: '))
print(f'{a} + {b} = {a + b}')
print(f'{a} - {b} = {a - b}')
print(f'{a} * {b} = {a * b}')
print(f'{a} / {b} = {a / b:.2f}')
print(f'{a} // {b} = {a // b}')
print(f'{a} % {b} = {a % b}')
print(f'{a} ** {b} = {a ** b}')
# Out:
# 2 + 3 = 5
# 2 - 3 = -1
# 2 * 3 = 6
# 2 / 3 = 0.67
# 2 // 3 = 0
# 2 % 3 = 2
# 2 ** 3 = 8

# %%
# formating numbers with f-strings:
pi = 3.141592653589793
print(f'Pi rounded to 2 decimal places: {pi:.2f}')
print(f'Pi rounded to 4 decimal places: {pi:.4f}')
print(f'Pi in scientific notation: {pi:.2e}')
# Out:
# Pi rounded to 2 decimal places: 3.14
# Pi rounded to 4 decimal places: 3.1416
# Pi in scientific notation: 3.14e+00

# %%
# formating with spaces:
s = 'Hello'
a = 123.456
print(f'|{s:10}|')  # string is left-aligned by default
print(f'|{a:10}|')  # number is right-aligned by default
# Out:
# |Hello     |
# |   123.456|

# %%
# formating with spaces and alignment:
print(f'|{s:>10}|')  # right-aligned
print(f'|{a:<10}|')  # left-aligned
print(f'|{s:^10}|')  # centered
# Out:
# |     Hello|
# |123.456   |
# |  Hello   |

# %%
name = input('Enter your name: ')
age = int(input('Enter your age: '))
grade = float(input('Enter your grade: '))

print(f'{'Name':<6}: {name:>10}')
print(f'{'Age':<6}: {age:>10}')
print(f'{'Grade':<6}: {grade:>10.2f}')
# Out:
# Name  :       John
# Age   :         20
# Grade :       8.50

# %%
product = input('Enter product name: ')
price = float(input('Enter product price: '))
discount = float(input('Enter discount percentage: '))

discount_price = price * discount / 100
net_price = price - discount_price

# %%
print(f'{'Product':<10}: {product:>20}')
print(f'{'Price':<10}: {price:>19.2f}$')
print(f'{'Discount':<10}: {discount_price:>19.2f}$')
print(f'{'Net Price':<10}: {net_price:>19.2f}$')
# Out:
# Product   :             Computer
# Price     :             1000.00$
# Discount  :              100.00$
# Net Price :              900.00$

# %%
s = '+' + '-' * 10
print(f'{s * 4}+')
print(f'|{"Product":<10}|{"Price":>10}|{"Discount":>10}|{"Net":>10}|')
print(f'{s * 4}+')
print(f'|{product:<10}|{price:>10}|{discount_price:>10}|{net_price:>10}|')
print(f'{s * 4}+')
# Out:
# +----------+----------+----------+----------+
# |Product   |     Price|  Discount|       Net|
# +----------+----------+----------+----------+
# |Computer  |    1000.0|     100.0|     900.0|
# +----------+----------+----------+----------+
